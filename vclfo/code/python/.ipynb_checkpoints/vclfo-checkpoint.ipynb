# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
import IPython.display as ipd
from ipynb.fs.defs.utility import *
from dataclasses import dataclass

# %%
# min frequency of each oscillator
VCO_F_MIN, VCO_F_MAX = 40, 20000
LFO_F_MIN, LFO_F_MAX = 1/60, 1000

WAVE_SIN, WAVE_TRI, WAVE_SAW, WAVE_SQR = 0, 1, 2, 3 # wavetable shape indices
NUM_WAVES = 4

# %%
class Wavetable:

    def __init__(self, smpl_size, num_octaves, num_waves, max_harmonics=1024):

        t = np.linspace(0, 1, smpl_size, endpoint=False)
        x = 2*np.pi*t
#         num_harmonics_per_octave = [int(max_harmonics/(2**i)) for i in range(num_octaves)]
    
        # set the maximum number of harmonics for a given octave
        num_harmonics_per_octave = [clamp(int(1024/(2**i)), 1, max_harmonics) for i in range(num_octaves)]

        # allocate empty arrays for the wavetables
        wavetable = []
        sine_samples, tri_samples, saw_samples, square_samples = ([] for _ in range(num_waves))
        
        # generate a band-limited wavetable for each octave
        for i in range(num_octaves):
            
            # add the first harmonic to each wave type
            sine_samples.append(np.sin(x))
            w_tri = w_saw = w_square = np.sin(x)
            
            # zero out the phase increments
            tri_offs = saw_offs = square_offs = 0
            
            # process harmonics higher than the first
            for k in range(2, num_harmonics_per_octave[i]+1):
                if k % 2 != 0: # only odd harmonics
                    # tri
                    tri_offs += np.pi
                    new_wave_tri = (1/(k*k)) * np.sin(x*k + tri_offs)
                    w_tri = [a + b for a, b in zip(w_tri, new_wave_tri)]

                    # square
                    new_wave_square = (1/k) * np.sin(x*k)
                    w_square = [a + b for a, b in zip(w_square, new_wave_square)]

                # saw
                saw_offs += np.pi
                new_wave_saw = (1/k) * np.sin(x*k + saw_offs)
                w_saw = [a + b for a, b in zip(w_saw, new_wave_saw)]


            tri_samples.append(normalize(w_tri))
            saw_samples.append(normalize(w_saw))
            square_samples.append(normalize(w_square))

        wavetable.append(sine_samples) # sine
        wavetable.append(tri_samples) # triangle
        wavetable.append(saw_samples) # saw    
        wavetable.append(square_samples) # square
        
        wavetable = list(np.concatenate(wavetable).flat)

        self.smpl_size = smpl_size
        self.num_octaves = num_octaves
        self.num_waves = num_waves
        self.wavetable = wavetable
    
    def get_smpl_size(self):
        return self.smpl_size
    
    def get_num_octaves(self):
        return self.num_octaves
    
    def get_wavetable(self):
        return self.wavetable
    
    def get_table_for_shape(self, wave_shape):
        table_size = self.smpl_size * self.num_octaves
        start_idx = wave_shape * table_size
        return self.wavetable[start_idx:start_idx+table_size]
    
    def get_wave_cycle(self, wave_shape, oct_idx=0):
        table_size = self.smpl_size * self.num_octaves
        wave_shape_start_idx = wave_shape * table_size
        start_idx = wave_shape_start_idx + oct_idx*self.smpl_size
        return self.wavetable[start_idx:start_idx+self.smpl_size]
        
    def lookup(self, wave_shape, octave_idx, sample_idx):
        i,j,k = wave_shape, octave_idx, sample_idx
        return self.wavetable[self.smpl_size*((self.num_octaves*i)+j) + k]


    # returns a sample from the wave table for wave with frequency f and wavetable index wt_idx
    # - wt_idx in range [0, SMPL_SIZE]
    def sample(self, wave_shape, f, wt_idx):
        # clamp the inputs
        wave_shape = clamp(wave_shape, 0, self.num_waves-1)
        f = clamp(f, LFO_F_MIN, VCO_F_MAX)
        
        # wavetable only defined at integer waveshape indices
        wave_shape_int = int(wave_shape)

        i = y1 = y2 = 0
            
        while i < 2:
            if wave_shape_int > self.num_waves-1:
                y2 = y1
                break
            
            # compute indices of adjacent band-limited wavetables that bound the input frequency
            oct_idx = max(0, int(np.log2(f))-2) # the index of the wavetable that lower bounds the input frequency
            oct_idx_plus_1 = min(oct_idx+1, self.num_octaves-1) # the index of the adjacent wavetable   

            # compute integer sample indices that surround wt_idx
            x0 = int(wt_idx)
            x1 = x0 + 1 % self.smpl_size

            # sample BL table 1 using linear interpolation
            samp_for_x0_oct0 = self.lookup(wave_shape_int, oct_idx, x0)
            samp_for_x1_oct0 = self.lookup(wave_shape_int, oct_idx, x1)
            samp1 = lerp2d(x0, samp_for_x0_oct0, x1, samp_for_x1_oct0, wt_idx)

            # sample BL table 2 using linear interpolation
            samp_for_x0_oct1 = self.lookup(wave_shape_int, oct_idx_plus_1, x0)
            samp_for_x1_oct1 = self.lookup(wave_shape_int, oct_idx_plus_1, x1)
            samp2 = lerp2d(x0, samp_for_x0_oct1, x1, samp_for_x1_oct1, wt_idx)

            # morph between samples based on pitch input
            p_lo = 2**(2 + oct_idx)
            p_hi = p_lo*2
            if oct_idx == 0:
                p_lo = 0
            p_weight = translate_range(f, p_lo, p_hi, 0, 1)
            
            y = lerp1d(samp1, samp2, p_weight)
            
            if i == 0:
                y1 = y
            else:
                y2 = y
                
            wave_shape_int += 1
            i += 1
            
        y = lerp1d(y1, y2, wave_shape % 1)

        return y

wavetable_test = Wavetable(smpl_size=2048, num_octaves=12, num_waves=4, max_harmonics=1024)
wt_array = wavetable_test.get_wavetable()

def plot_wavetable(wavetable, wave_shape):
    plt.figure()
    plt.plot(wavetable_test.get_table_for_shape(wave_shape))

def plot_band_limited_tables(wavetable, wave_shape):
    plt.figure()
    for oct_idx in range(wavetable.get_num_octaves()):
        plt.plot(wavetable.get_wave_cycle(wave_shape, oct_idx))
        
plot_wavetable(wavetable_test, WAVE_SAW)
plot_band_limited_tables(wavetable_test, WAVE_SAW)

# %%
class Playback:
    
    def __init__(self, FS, dur):
        self.FS = FS
        self.set_dur(dur)

    def set_dur(self, dur):
        self.dur = dur
        self.N = int(self.FS * dur)  
        
    def get_dur(self):
        return self.dur
    
    def get_N(self):
        return self.N

    def play(self, wavetable, test_dict, listen=True, plot=True, show_progress=False):
        cv_col = CV_stream_collection()
        
        # parse the test dictionary
        for k in test_dict.keys():
            ch = None
            if k == 'waveshape':
                ch = CV_CH_WAVESHAPE
            elif k == 'mode':
                ch = CV_CH_MODE
            elif k == 'coarse_adj':
                ch = CV_CH_COARSE_ADJ
            elif k == 'fine_adj':
                ch = CV_CH_FINE_ADJ
            elif k == 'vpo':
                ch = CV_CH_VPO
            elif k == 'fm_exp':
                ch = CV_CH_FM_EXP
            cv_col.add_stream(CV_stream(ch, test_dict[k]))

        # create N samples
        output = []
        wt_idx = 0
        for i in range(self.N):

            # get the cv for this sample
            cv_ss = cv_col.get_snapshot_at(i)
            
            # extract the cv for each channel
            waveshape = cv_ss.get_channel(CV_CH_WAVESHAPE)
            mode = cv_ss.get_channel(CV_CH_MODE)
            coarse_adj = cv_ss.get_channel(CV_CH_COARSE_ADJ)
            fine_adj = cv_ss.get_channel(CV_CH_FINE_ADJ)
            vpo = cv_ss.get_channel(CV_CH_VPO)
            fm_exp = cv_ss.get_channel(CV_CH_FM_EXP)

            # determine the desired frequency
            f = translate_range(coarse_adj.get_converted(), coarse_adj.range_min, coarse_adj.range_max, VCO_F_MIN, VCO_F_MAX)
            volt_from_vpo = vpo.get_raw()
            f *= 2**volt_from_vpo
            volt_from_fm = fm_exp.get_raw()
            f *= 2**volt_from_fm

            # clamp the frequency to within allowable range
            f = clamp(f, VCO_F_MIN, VCO_F_MAX)

            # take two samples from adjacent waveshapes and interpolate between them based on CV
            y = wavetable.sample(waveshape.get_raw(), f, wt_idx)
            output.append(y)   

            # update the (decimal) index in the wave sample
            smpl_size = wavetable.get_smpl_size()
            wt_idx += smpl_size * f/self.FS # adjust the playback rate
            wt_idx %= smpl_size # keep wt_idx in wavetable index range

            # progress indication
            if show_progress:
                prog = 100*i/self.N
                if prog % 10 == 0:
                    print(prog, "%")

        wave = np.array(output)
    
        if listen:
            display(ipd.Audio(wave, rate=self.FS))
        if plot:
            plt.plot(wave)    

        return wave

# %%
### CV ####

CV_CH_WAVESHAPE = 0
CV_CH_MODE = 1
CV_CH_COARSE_ADJ = 2
CV_CH_FINE_ADJ = 3
CV_CH_VPO = 4
CV_CH_FM_EXP = 5

# specifies the raw value ranges for each CV channel
ranges = {
    CV_CH_WAVESHAPE: (0,1),
    CV_CH_MODE: (0,1),
    CV_CH_COARSE_ADJ: (0,1),
    CV_CH_FINE_ADJ: (0,1),
    CV_CH_VPO: (-5,5),
    CV_CH_FM_EXP: (-5,5)
}

class CV:
    ### a CV input belonging to a specified channel ###
    ### the input and input range are specified ###
    ### the input is converted to the range [0,1] ###
    
    def __init__(self, channel, raw_val):
        self.channel = channel
        self.range_min, self.range_max = ranges[channel]
        self.raw_val = raw_val
        self.converted_val = translate_range(raw_val, self.range_min, self.range_max, 0, 1)
        
    def get_raw(self):
        return self.raw_val
    
    def get_converted(self):
        return self.converted_val

class CV_stream:
    ### a stream of CV values ###
    
    def __init__(self, channel, stream_list):
        self.stream = [CV(channel, val) for val in stream_list]

    def get(self, i):
        if i < 0 or i >= len(self.stream):
            return 0
        return self.stream[i]

class CV_stream_collection:
    ### a collection of CV streams ###
    
    def __init__(self):
        self.cv_collection = []
        
    def add_stream(self, stream):
        self.cv_collection.append(stream)
        
    def get_snapshot_at(self, i):
        return CV_snapshot([stream.get(i) for stream in self.cv_collection])

@dataclass
class CV_snapshot:
    ### represents a snapshot in time of CV values across all channels in a collection ###
    
    cv_values: [CV]
        
    def get_channel(self, channel):
        if channel < 0 or channel >= len(self.cv_values):
            return 0
        return self.cv_values[channel]

class CV_sim:
    ### a module that generates simulated CV inputs for a specified duration ###
    
    def __init__(self, playback):
        self.playback = playback
        
    def const_inp(self, val):
        return [val] * self.playback.get_N()
    
    def ramp_inp(self, from_val, to_val):
        return np.linspace(from_val, to_val, self.playback.get_N())

    def sin_inp(self, A, f):
        t = np.linspace(0, self.playback.get_dur(), self.playback.get_N())
        return A*np.sin(2*np.pi*t*f)

# %%
### TESTS ####

SMPL_SIZE = 2048 # number of samples for each wave cycle in the wavetable
NUM_OCTAVES = 12

wavetable = Wavetable(smpl_size=SMPL_SIZE, num_octaves=NUM_OCTAVES, num_waves=NUM_WAVES)
pb = Playback(FS=48000, dur=3)
cvsim = CV_sim(pb)

wavetable_poor = Wavetable(smpl_size=SMPL_SIZE, num_octaves=NUM_OCTAVES, num_waves=NUM_WAVES, max_harmonics=8)

# %%
###### TEST FREQUENCY SWEEP ######
test_dict = {
    'waveshape': cvsim.const_inp(WAVE_SAW),
    'mode': cvsim.const_inp(0),
    'coarse_adj': cvsim.ramp_inp(0.01, 0.05),
    'fine_adj': cvsim.const_inp(0),
    'vpo': cvsim.const_inp(0),
    'fm_exp': cvsim.const_inp(0),
}
pb.play(wavetable, test_dict, plot=False)
pb.play(wavetable_poor, test_dict, plot=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([4.64152717e-17, 1.10735622e-04, 8.73798663e-04, ...,
#        7.23715254e-01, 8.54201614e-01, 9.57288399e-01])

# %%
###### TEST 1 volt/octave AT CONSTANT COARSE FREQUENCY ######
test_dict = {
    'waveshape': cvsim.const_inp(WAVE_SIN),
    'mode': cvsim.const_inp(0),
    'coarse_adj': cvsim.const_inp(0.01),
    'fine_adj': cvsim.const_inp(0),
    'vpo': cvsim.sin_inp(1, 0.33), # sine w/ A=1, f=0.33Hz
    'fm_exp': cvsim.const_inp(0),
}
pb.play(wavetable, test_dict, plot=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([ 0.        ,  0.0313584 ,  0.06268687, ..., -0.94260044,
#        -0.93215003, -0.92085935])

# %%
##### TEST FREQUENCY MODULATION ON CONSTANT PITCH #####
test_dict = {
    'waveshape': cvsim.const_inp(WAVE_SIN),
    'mode': cvsim.const_inp(0),
    'coarse_adj': cvsim.const_inp(0.01),
    'fine_adj': cvsim.const_inp(0),
    'vpo': cvsim.const_inp(0),
    'fm_exp': cvsim.sin_inp(A=0.3, f=3),
}
pb.play(wavetable, test_dict, plot=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([ 0.        ,  0.0313584 ,  0.06268849, ..., -0.46160793,
#        -0.48919397, -0.51630143])

# %%
##### TEST FREQUENCY MODULATION ON RAMPING PITCH #####
test_dict = {
    'waveshape': cvsim.const_inp(WAVE_SIN),
    'mode': cvsim.const_inp(0),
    'coarse_adj': cvsim.ramp_inp(0.015, 0.030),
    'fine_adj': cvsim.const_inp(0),
    'vpo': cvsim.const_inp(0),
    'fm_exp': cvsim.sin_inp(A=1, f=30),
}
pb.play(wavetable, test_dict, plot=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([ 0.        ,  0.04441269,  0.08885873, ..., -0.95787548,
#        -0.97842035, -0.99223032])

# %%
### TEST WAVE SHAPE MORPHING ###
test_dict = {
    'waveshape': cvsim.ramp_inp(0, NUM_WAVES),
    'mode': cvsim.const_inp(0),
    'coarse_adj': cvsim.const_inp(0.015),
    'fine_adj': cvsim.const_inp(0),
    'vpo': cvsim.const_inp(0),
    'fm_exp': cvsim.const_inp(0),
}
pb.play(wavetable, test_dict, plot=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-106-bfbfbdf96dd1> in <module>
#       8     'fm_exp': cvsim.const_inp(0),
#       9 }
# ---> 10 pb.play(wavetable, test_dict, plot=False)
#
# <ipython-input-99-56957451599e> in play(self, wavetable, test_dict, listen, plot, show_progress)
#      62
#      63             # take two samples from adjacent waveshapes and interpolate between them based on CV
# ---> 64             y = wavetable.sample(waveshape.get_raw(), f, wt_idx)
#      65             output.append(y)
#      66
#
# <ipython-input-98-c83993a413f5> in sample(self, wave_shape, f, wt_idx)
#     105
#     106             # sample BL table 1 using linear interpolation
# --> 107             samp_for_x0_oct0 = self.lookup(wave_shape_int, oct_idx, x0)
#     108             samp_for_x1_oct0 = self.lookup(wave_shape_int, oct_idx, x1)
#     109             samp1 = lerp2d(x0, samp_for_x0_oct0, x1, samp_for_x1_oct0, wt_idx)
#
# <ipython-input-98-c83993a413f5> in lookup(self, wave_shape, octave_idx, sample_idx)
#      80     def lookup(self, wave_shape, octave_idx, sample_idx):
#      81         i,j,k = wave_shape, octave_idx, sample_idx
# ---> 82         return self.wavetable[self.smpl_size*((self.num_octaves*i)+j) + k]
#      83
#      84
#
# IndexError: list index out of range
